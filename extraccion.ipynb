# %% [markdown]
# <a href="https://colab.research.google.com/github/lizeethmm/lizeethmm/blob/main/extraccion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import io

# %%
#cargar archivo csv desde equipo
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-35ab171a-8465-471d-9178-1f66395b1000" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-35ab171a-8465-471d-9178-1f66395b1000">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#convertir en dataframe
df= pd.read_csv("CountryTable.csv")
df
# Out:
#     code          name      continent                     region  \
# 0    ABW         Aruba  North America                  Caribbean
# 1    AFG   Afghanistan           Asia  Southern and Central Asia
# 2    AGO        Angola         Africa             Central Africa
# 3    AIA      Anguilla  North America                  Caribbean
# 4    ALB       Albania         Europe            Southern Europe
# ..   ...           ...            ...                        ...
# 234  YEM         Yemen           Asia                Middle East
# 235  YuG    Yugoslavia         Europe            Southern Europe
# 236  ZAF  South Africa         Africa            Southern Africa
# 237  ZMB        Zambia         Africa             Eastern Africa
# 238  ZWE      Zimbabwe         Africa             Eastern Africa
#
#      surface_area  independence_year  population  life_expectancy       gnp  \
# 0           193.0                NaN      103000             78.4     828.0
# ...

# %%
#filtro por objeto de la columna name de la fila zimbabwe
filtro1=df[df["name"] == "Zimbabwe"]
filtro1
# Out:
#     code      name continent          region  surface_area  independence_year  \
# 238  ZWE  Zimbabwe    Africa  Eastern Africa      390757.0             1980.0
#
#      population  life_expectancy     gnp  gnp_old local_name government_form  \
# 238    11669000             37.8  5951.0   8670.0   Zimbabwe        Republic
#
#         head_of_state  capital code2
# 238  Robert G. Mugabe   4068.0    ZW

# %%
#filtro por objeto de la columna continente de la fila asia
filtro12=df[df["continent"] == "Asia"]
filtro12
# Out:
#     code                  name continent                     region  \
# 1    AFG           Afghanistan      Asia  Southern and Central Asia
# 7    ARE  united Arab Emirates      Asia                Middle East
# 9    ARM               Armenia      Asia                Middle East
# 16   AZE            Azerbaijan      Asia                Middle East
# 21   BGD            Bangladesh      Asia  Southern and Central Asia
# 23   BHR               Bahrain      Asia                Middle East
# 32   BRN                Brunei      Asia             Southeast Asia
# 33   BTN                Bhutan      Asia  Southern and Central Asia
# 41   CHN                 China      Asia               Eastern Asia
# 54   CYP                Cyprus      Asia                Middle East
# 77   GEO               Georgia      Asia                Middle East
# 92   HKG             Hong Kong      Asia               Eastern Asia
# 98   IDN             Indonesia      Asia             Southeast Asia
# ...

# %%
#filtro por filas, de la fila 0 a la 200
filtro21= df.iloc[0:200, : ]
filtro21
# Out:
#     code                       name      continent                     region  \
# 0    ABW                      Aruba  North America                  Caribbean
# 1    AFG                Afghanistan           Asia  Southern and Central Asia
# 2    AGO                     Angola         Africa             Central Africa
# 3    AIA                   Anguilla  North America                  Caribbean
# 4    ALB                    Albania         Europe            Southern Europe
# ..   ...                        ...            ...                        ...
# 195  SPM  Saint Pierre and Miquelon  North America              North America
# 196  STP      Sao Tome and Principe         Africa             Central Africa
# 197  SuR                   Suriname  South America              South America
# 198  SVK                   Slovakia         Europe             Eastern Europe
# 199  SVN                   Slovenia         Europe            Southern Europe
#
# ...

# %%
#filtro por filas. Se filtra la fila 43, 68 y 71
filtro22=df.iloc[[43, 68, 71], : ] #filas no consecutivas
filtro22
# Out:
#    code              name      continent          region  surface_area  \
# 43  CMR          Cameroon         Africa  Central Africa      475442.0
# 68  ETH          Ethiopia         Africa  Eastern Africa     1104300.0
# 71  FLK  Falkland Islands  South America   South America       12173.0
#
#     independence_year  population  life_expectancy     gnp  gnp_old  \
# 43             1960.0    15085000             54.8  9174.0   8596.0
# 68            -1000.0    62565000             45.2  6353.0   6180.0
# 71                NaN        2000              NaN     0.0      NaN
#
#            local_name                government_form   head_of_state  capital  \
# 43  Cameroun/Cameroon                       Republic       Paul Biya   1804.0
# 68        YeItyop iya                       Republic  Negasso Gidada    756.0
# 71   Falkland Islands  Dependent Territory of the uK    Elisabeth II    763.0
#
#    code2
# 43    CM
# 68    ET
# 71    FK

# %%
#Filtro por columnas. Se filtro la columna 3 y 5
filtro31=df.iloc[ : , 3:5]
filtro31
# Out:
#                         region  surface_area
# 0                    Caribbean         193.0
# 1    Southern and Central Asia      652090.0
# 2               Central Africa     1246700.0
# 3                    Caribbean          96.0
# 4              Southern Europe       28748.0
# ..                         ...           ...
# 234                Middle East      527968.0
# 235            Southern Europe      102173.0
# 236            Southern Africa     1221037.0
# 237             Eastern Africa      752618.0
# 238             Eastern Africa      390757.0
#
# [239 rows x 2 columns]

# %%
#Filtro por columnas
filtro32=df.iloc[ : , [1,3,5]] #columnas no consecutivas
filtro32
#Se filtraron las columnas 1, 3 y 5
# Out:
#              name                     region  independence_year
# 0           Aruba                  Caribbean                NaN
# 1     Afghanistan  Southern and Central Asia             1919.0
# 2          Angola             Central Africa             1975.0
# 3        Anguilla                  Caribbean                NaN
# 4         Albania            Southern Europe             1912.0
# ..            ...                        ...                ...
# 234         Yemen                Middle East             1918.0
# 235    Yugoslavia            Southern Europe             1918.0
# 236  South Africa            Southern Africa             1910.0
# 237        Zambia             Eastern Africa             1964.0
# 238      Zimbabwe             Eastern Africa             1980.0
#
# [239 rows x 3 columns]

# %%
#filtro por columnas y por filas
filtro_mix=df.iloc[ [43,68,71] , 3:5]
filtro_mix
#Se filtraron las columnas 3 y 5; y las filas 43, 68 y 71
# Out:
#             region  surface_area
# 43  Central Africa      475442.0
# 68  Eastern Africa     1104300.0
# 71   South America       12173.0

# %%
#filtro por columnas y por filas
filtrofresh=df.iloc[ : , [1,3,5]] #columnas no consecutivas
filtrofresh
#se filtrearon columnas no consecutivas (1, 3 y 5)
# Out:
#              name                     region  independence_year
# 0           Aruba                  Caribbean                NaN
# 1     Afghanistan  Southern and Central Asia             1919.0
# 2          Angola             Central Africa             1975.0
# 3        Anguilla                  Caribbean                NaN
# 4         Albania            Southern Europe             1912.0
# ..            ...                        ...                ...
# 234         Yemen                Middle East             1918.0
# 235    Yugoslavia            Southern Europe             1918.0
# 236  South Africa            Southern Africa             1910.0
# 237        Zambia             Eastern Africa             1964.0
# 238      Zimbabwe             Eastern Africa             1980.0
#
# [239 rows x 3 columns]

# %%
#Filtro de filas vs columnas
#Paso 1: Leemos el contenido del archivo
from google.colab import files
uploaded=files.upload()
df=pd.read_csv(io.BytesIO(uploaded['CountryTable.csv']), index_col=3)
df
# Out:
#      <input type="file" id="files-e22114cf-71d4-4c87-9e12-0e0c4bd974be" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e22114cf-71d4-4c87-9e12-0e0c4bd974be">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Filtro de filas vs columnas
#Paso 1: Leemos el contenido del archivo
from google.colab import files
uploaded=files.upload()
df=pd.read_csv(io.BytesIO(uploaded['CountryTable.csv']), index_col=1)
df
#Paso 2: Aplicamos filtro de filas vs columnas
filtro4=df.loc[["Aruba","Angola"], ["region"]]
filtro4
#Filtramos Aruba y Angola de filas y en columnas la region
# Out:
#      <input type="file" id="files-66c0a1ae-a9b1-4724-9340-e11ea90e1734" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-66c0a1ae-a9b1-4724-9340-e11ea90e1734">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Filtro de filas vs columnas
#Paso 1: Leemos el contenido del archivo
from google.colab import files
uploaded=files.upload()
df=pd.read_csv(io.BytesIO(uploaded['CountryTable.csv']), index_col=11)
df
#Paso 2: Aplicamos filtro de filas vs columnas
filtro42=df.loc[["Republic","Socialistic Republic"], ["population"]]
filtro42 
#Aplicamos el filtro de filas para obtener republicas y republicas socialistas y en cuanto a columnas la población
# Out:
#      <input type="file" id="files-947271ff-36f5-4e32-a33d-196c7b145460" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-947271ff-36f5-4e32-a33d-196c7b145460">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Filtro por cabecera
filtro51=df.head(4)
filtro51
#Filtramos los primeros cuatro datos
# Out:
#                                              code         name      continent  \
# government_form
# Nonmetropolitan Territory of The Netherlands  ABW        Aruba  North America
# Islamic Emirate                               AFG  Afghanistan           Asia
# Republic                                      AGO       Angola         Africa
# Dependent Territory of the uK                 AIA     Anguilla  North America
#
#                                                                  region  \
# government_form
# Nonmetropolitan Territory of The Netherlands                  Caribbean
# Islamic Emirate                               Southern and Central Asia
# Republic                                                 Central Africa
# Dependent Territory of the uK                                 Caribbean
#
#                                               surface_area  independence_year  \
# government_form
# Nonmetropolitan Territory of The Netherlands         193.0                NaN
# ...

# %%
#Filtro por cabecera
filtro52=df.head(3)
filtro52
#filtramos los primeros tres datos de la tabla
# Out:
#                                              code         name      continent  \
# government_form
# Nonmetropolitan Territory of The Netherlands  ABW        Aruba  North America
# Islamic Emirate                               AFG  Afghanistan           Asia
# Republic                                      AGO       Angola         Africa
#
#                                                                  region  \
# government_form
# Nonmetropolitan Territory of The Netherlands                  Caribbean
# Islamic Emirate                               Southern and Central Asia
# Republic                                                 Central Africa
#
#                                               surface_area  independence_year  \
# government_form
# Nonmetropolitan Territory of The Netherlands         193.0                NaN
# Islamic Emirate                                   652090.0             1919.0
# ...

# %%
#Filtro por comparacion
filtro61=df[df["continent"] == "Africa"]
filtro61
#filtramos la columna de continente para solo obtener la de Africa
# Out:
#                                    code  \
# government_form
# Republic                            AGO
# Republic                            BDI
# Republic                            BEN
# Republic                            BFA
# Republic                            BWA
# Republic                            CAF
# Republic                            CIV
# Republic                            CMR
# Republic                            COD
# Republic                            COG
# Republic                            COM
# Republic                            CPV
# Republic                            DJI
# Republic                            DZA
# Republic                            EGY
# Republic                            ERI
# Occupied by Marocco                 ESH
# Republic                            ETH
# Republic                            GAB
# Republic                            GHA
# Republic                            GIN
# Republic                            GMB
# ...

# %%
#Filtro por comparacion
filtro62=df[df["name"] == "Angola"]
filtro62
#filtramos la columna name para solo obtener datos de Angola
# Out:
#                 code    name continent          region  surface_area  \
# government_form
# Republic         AGO  Angola    Africa  Central Africa     1246700.0
#
#                  independence_year  population  life_expectancy     gnp  \
# government_form
# Republic                    1975.0    12878000             38.3  6648.0
#
#                  gnp_old local_name            head_of_state  capital code2
# government_form
# Republic          7984.0     Angola  Jose Eduardo dos Santos     56.0    AO

# %%
#Filtro Y
filtro71=df[(df["independence_year"] == 1960) & (df["continent"] =="Africa") & (df["region"] == "Central Africa")]
filtro71
#filtramos que el año de independencia sea solo para 1960 que el continente sea solo Africa y que la region solo sea para Central Africa
# Out:
#                 code                                   name continent  \
# government_form
# Republic         CAF               Central African Republic    Africa
# Republic         CMR                               Cameroon    Africa
# Republic         COD  Congo, The Democratic Republic of the    Africa
# Republic         COG                                  Congo    Africa
# Republic         GAB                                  Gabon    Africa
# Republic         TCD                                   Chad    Africa
#
#                          region  surface_area  independence_year  population  \
# government_form
# Republic         Central Africa      622984.0             1960.0     3615000
# Republic         Central Africa      475442.0             1960.0    15085000
# Republic         Central Africa     2344858.0             1960.0    51654000
# Republic         Central Africa      342000.0             1960.0     2943000
# ...

# %%
#Filtro Y
filtro72=df[(df["capital"] > 902) & (df["life_expectancy"]>50) & (df["gnp"] < 6000)]
filtro72
#Filtramos que el capital nos de solo para mayores a 902 al igual que life expentancy >50 y que GNP sea para menores de 6000
# Out:
#                               code                              name  \
# government_form
# Republic                       COM                           Comoros
# Republic                       CPV                        Cape Verde
# Republic                       EST                           Estonia
# Federal Republic               FSM   Micronesia, Federated States of
# Dependent Territory of the uK  GIB                         Gibraltar
# ...                            ...                               ...
# Constitutional Monarchy        TuV                            Tuvalu
# Constitutional Monarchy        VCT  Saint Vincent and the Grenadines
# uS Territory                   VIR              Virgin Islands, u.S.
# Republic                       VuT                           Vanuatu
# Parlementary Monarchy          WSM                             Samoa
#
#                                    continent            region  surface_area  \
# government_form
# ...

# %%
#Filtro 8
filtro81=df[(df["continent"]== "Oceania") | (df["capital"] > 2000)]
filtro81
#Se filtraron todos los datos que fueran de oceania o que su capital fuera mayor a 2000
# Out:
#                                     code                     name continent  \
# government_form
# uS Territory                         ASM           American Samoa   Oceania
# Constitutional Monarchy, Federation  AuS                Australia   Oceania
# Republic                             BLR                  Belarus    Europe
# Territory of Australia               CCK  Cocos (Keeling) Islands   Oceania
# Federation                           CHE              Switzerland    Europe
# ...                                  ...                      ...       ...
# Republic                             VuT                  Vanuatu   Oceania
# Nonmetropolitan Territory of France  WLF        Wallis and Futuna   Oceania
# Parlementary Monarchy                WSM                    Samoa   Oceania
# Republic                             ZMB                   Zambia    Africa
# Republic                             ZWE                 Zimbabwe    Africa
#
# ...

# %%
#Filtro 8
filtro82=df[(df["life_expectancy"] <50) | (df["continent"]=="Oceania")]
filtro82
#Se obtuvieron todos los datos que tuvieran una expectativa de vida menor a 50 o que fueran de oceanía
# Out:
#                                          code  \
# government_form
# Islamic Emirate                           AFG
# Republic                                  AGO
# uS Territory                              ASM
# Constitutional Monarchy, Federation       AuS
# Republic                                  BDI
# Republic                                  BFA
# Republic                                  BWA
# Republic                                  CAF
# Territory of Australia                    CCK
# Republic                                  CIV
# Republic                                  COD
# Republic                                  COG
# Nonmetropolitan Territory of New Zealand  COK
# Territory of Australia                    CXR
# Occupied by Marocco                       ESH
# Republic                                  ETH
# Republic                                  FJI
# Federal Republic                          FSM
# Republic                                  GIN
# ...

# %%
#Filtro not
filtro91=df[~(df["continent"]=="Africa") & ~(df["head_of_state"]== "Elisabeth II")]
filtro91
#Todos los datos que no sean del continente de África  y que la cabeza de estado no fuera Elisabeth II
# Out:
#                                              code                  name  \
# government_form
# Nonmetropolitan Territory of The Netherlands  ABW                 Aruba
# Islamic Emirate                               AFG           Afghanistan
# Republic                                      ALB               Albania
# Parliamentary Coprincipality                  AND               Andorra
# Nonmetropolitan Territory of The Netherlands  ANT  Netherlands Antilles
# ...                                           ...                   ...
# Republic                                      VuT               Vanuatu
# Nonmetropolitan Territory of France           WLF     Wallis and Futuna
# Parlementary Monarchy                         WSM                 Samoa
# Republic                                      YEM                 Yemen
# Federal Republic                              YuG            Yugoslavia
#
#                                                   continent  \
# government_form
# ...

# %%
#Filtro not
filtro92=df[~(df["code"]=="COK") & ~(df["name"]== "Yugoslavia")]
filtro92
#Todos los datos que no fueran de código COK y que tampoco fuera Yugoslavia
# Out:
#                                              code          name  \
# government_form
# Nonmetropolitan Territory of The Netherlands  ABW         Aruba
# Islamic Emirate                               AFG   Afghanistan
# Republic                                      AGO        Angola
# Dependent Territory of the uK                 AIA      Anguilla
# Republic                                      ALB       Albania
# ...                                           ...           ...
# Parlementary Monarchy                         WSM         Samoa
# Republic                                      YEM         Yemen
# Republic                                      ZAF  South Africa
# Republic                                      ZMB        Zambia
# Republic                                      ZWE      Zimbabwe
#
#                                                   continent  \
# government_form
# Nonmetropolitan Territory of The Netherlands  North America
# ...

# %%
#Convertir archivo filtrado a CSV
filtro1.to_csv("filtro1.csv")
filtro12.to_csv("filtro12.csv")
filtro21.to_csv("filtro21.csv")
filtro22.to_csv("filtro22.csv")
filtro31.to_csv("filtro31.csv")
filtro32.to_csv("filtro32.csv")
filtro_mix.to_csv("filtromix.csv")
filtrofresh.to_csv("filtrofresh.csv")
filtro4.to_csv("filtro4.csv")
filtro42.to_csv("filtro42.csv")
filtro51.to_csv("filtro51.csv")
filtro52.to_csv("filtro52.csv")
filtro61.to_csv("filtro61.csv")
filtro62.to_csv("filtro62.csv")
filtro71.to_csv("filtro71.csv")
filtro72.to_csv("filtro72.csv")
filtro81.to_csv("filtro81.csv")
filtro82.to_csv("filtro82.csv")
filtro91.to_csv("filtro91.csv")
filtro92.to_csv("filtro92.csv")

# %%
#Descargar archivo filtrado en csv
from google.colab import files

files.download("filtro1.csv")
files.download("filtro12.csv")
files.download("filtro21.csv")
files.download("filtro22.csv")
files.download("filtro31.csv")
files.download("filtro32.csv")
files.download("filtromix.csv")
files.download("filtrofresh.csv")
files.download("filtro4.csv")
files.download("filtro42.csv")
files.download("filtro51.csv")
files.download("filtro52.csv")
files.download("filtro61.csv")
files.download("filtro62.csv")
files.download("filtro71.csv")
files.download("filtro72.csv")
files.download("filtro81.csv")
files.download("filtro82.csv")
files.download("filtro91.csv")
files.download("filtro92.csv")
